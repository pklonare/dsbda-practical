# %%
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("iris.csv")
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.describe(include="object")
# Out:
#        variety
# count      150
# unique       3
# top     Setosa
# freq        50

# %%
data.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
print("The Feature in the dataset are as follows:")
print("1. sepal.length :",data["sepal.length"].dtype)
print("2. sepal.width :",data["sepal.width"].dtype)
print("3. petal.length :",data["petal.length"].dtype)
print("4. petal.width :",data["petal.width"].dtype)
print("5. variety :",data["variety"].dtype)
# Out:
# The Feature in the dataset are as follows:
# 1. sepal.length : float64
# 2. sepal.width : float64
# 3. petal.length : float64
# 4. petal.width : float64
# 5. variety : object

# %%
sns.histplot(x= data["sepal.length"], kde=True)
# Out:
# <AxesSubplot:xlabel='sepal.length', ylabel='Count'>

# %%
sns.histplot(x= data["sepal.width"], kde=True)
# Out:
# <AxesSubplot:xlabel='sepal.width', ylabel='Count'>

# %%
sns.histplot(x= data["petal.length"], kde=True)
# Out:
# <AxesSubplot:xlabel='petal.length', ylabel='Count'>

# %%
sns.histplot(x= data["petal.width"], kde=True)
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='Count'>

# %%
sns.histplot(x= data["variety"], kde=True)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='Count'>

# %%
sns.boxplot(x= data["sepal.length"])
# Out:
# <AxesSubplot:xlabel='sepal.length'>

# %%
sns.boxplot(x= data["sepal.width"])
# Out:
# <AxesSubplot:xlabel='sepal.width'>

# %%
sns.boxplot(x= data["petal.length"])
# Out:
# <AxesSubplot:xlabel='petal.length'>

# %%
sns.boxplot(x= data["petal.width"])
# Out:
# <AxesSubplot:xlabel='petal.width'>

# %%
sns.boxplot(x="sepal.length", y="variety",data=data)
# Out:
# <AxesSubplot:xlabel='sepal.length', ylabel='variety'>

# %%
sns.boxplot(x="petal.length", y="variety",data=data)
# Out:
# <AxesSubplot:xlabel='petal.length', ylabel='variety'>

# %%
sns.boxplot(x="sepal.width", y="variety",data=data)
# Out:
# <AxesSubplot:xlabel='sepal.width', ylabel='variety'>

# %%
sns.boxplot(x="petal.width", y="variety",data=data)
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='variety'>
